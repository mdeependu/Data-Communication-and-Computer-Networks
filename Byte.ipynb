# %%
name="mandaldeependu68"
binary=""
for i in name:
    asci=ord(i)
    binstore=str (bin(asci))
    binary=binary+binstore[ 2: : ]

binary=binary+" "
print(str(binary))
# Out:
# 11011011100001110111011001001100001110110011001001100101110010111100001100101110111011001001110101110110111000

# %%
flag="1110"
ESC="1001"
pckt=[ ]

for i in range (0, len(binary), 4):
    pckt.append(binary[i:i+4])
    print(pckt)
    
for i in range(0, len(pckt) ):
    if pckt[i]==flag:
        print("")
# Out:
# ['1101']
# ['1101', '1011']
# ['1101', '1011', '1000']
# ['1101', '1011', '1000', '0111']
# ['1101', '1011', '1000', '0111', '0111']
# ['1101', '1011', '1000', '0111', '0111', '0110']
# ['1101', '1011', '1000', '0111', '0111', '0110', '0100']
# ['1101', '1011', '1000', '0111', '0111', '0110', '0100', '1100']
# ['1101', '1011', '1000', '0111', '0111', '0110', '0100', '1100', '0011']
# ['1101', '1011', '1000', '0111', '0111', '0110', '0100', '1100', '0011', '1011']
# ['1101', '1011', '1000', '0111', '0111', '0110', '0100', '1100', '0011', '1011', '0011']
# ['1101', '1011', '1000', '0111', '0111', '0110', '0100', '1100', '0011', '1011', '0011', '0010']
# ['1101', '1011', '1000', '0111', '0111', '0110', '0100', '1100', '0011', '1011', '0011', '0010', '0110']
# ['1101', '1011', '1000', '0111', '0111', '0110', '0100', '1100', '0011', '1011', '0011', '0010', '0110', '0101']
# ...
